# %%
import re
import pandas as pd
import numpy as np
import tensorflow
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Bidirectional, LSTM, Dense, Dropout, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import nltk
nltk.download('stopwords')
# Out:
# Train samples: 31755, Test samples: 7939
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\admin\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
# Загрузка данных
train_df = pd.read_csv('data/train.csv')
test_df = pd.read_csv('data/test.csv')
print(f"Train samples: {len(train_df)}, Test samples: {len(test_df)}")

# %%
# Чистка данных
def preprocess_text(text):
    # Стоп-слова
    stop_words = stopwords.words('english')
    text = str(text).lower()
    text = re.sub(r'[^\w\s]', '', text)  # Удаление пунктуации
    text = re.sub(r'\d+', '', text)      # Удаление чисел
    text = ' '.join([word for word in text.split() if word not in stop_words and len(word) > 2])
    return text

train_df['cleaned_text'] = train_df['text'].apply(preprocess_text)
test_df['cleaned_text'] = test_df['text'].apply(preprocess_text)

# %%
# Параметры
max_words = 20000  # Увеличенный размер словаря
max_len = 30      # Увеличенная длина последовательности
embedding_dim = 300 # Большая размерность эмбеддингов

# Токенизация
tokenizer = Tokenizer(num_words=max_words, oov_token='<OOV>')
tokenizer.fit_on_texts(train_df['cleaned_text'])

X_train = pad_sequences(tokenizer.texts_to_sequences(train_df['cleaned_text']), maxlen=max_len)
X_test = pad_sequences(tokenizer.texts_to_sequences(test_df['cleaned_text']), maxlen=max_len)

# Кодирование меток
label_encoder = LabelEncoder()
y = label_encoder.fit_transform(train_df['target'])
num_classes = len(label_encoder.classes_)

# %%
# Примененеие GloVe
def load_glove_embeddings():
    embeddings_index = {}
    with open('data/glove.6B.300d.txt', encoding='utf8') as f:
        for line in f:
            values = line.split()
            word = values[0]
            coefs = np.asarray(values[1:], dtype='float32')
            embeddings_index[word] = coefs
    return embeddings_index

embeddings_index = load_glove_embeddings()

# %%
# Создание матрицы эмбеддингов
embedding_matrix = np.zeros((max_words, embedding_dim))
for word, i in tokenizer.word_index.items():
    if i < max_words and word in embeddings_index:
        embedding_matrix[i] = embeddings_index[word]

# %%
# Построение RNN модели
model = Sequential([
    Embedding(
        input_dim=max_words,
        output_dim=embedding_dim,
        input_length=max_len,
        weights=[embedding_matrix],
        trainable=False  # Закрепляем предобученные эмбеддинги
    ),
    Bidirectional(LSTM(258, return_sequences=True)), #258
    Dropout(0.3),
    BatchNormalization(),
    Bidirectional(LSTM(128)), #128
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dense(num_classes, activation='softmax')
])

model.compile(
    optimizer=Adam(learning_rate=0.001),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 30, 300)           6000000
#
#  bidirectional (Bidirectiona  (None, 30, 1024)         3330048
#  l)
#
#  dropout (Dropout)           (None, 30, 1024)          0
#
#  batch_normalization (BatchN  (None, 30, 1024)         4096
#  ormalization)
#
#  bidirectional_1 (Bidirectio  (None, 1024)             6295552
#  nal)
#
#  dropout_1 (Dropout)         (None, 1024)              0
#
#  dense (Dense)               (None, 128)               131200
#
#  dense_1 (Dense)             (None, 28)                3612
#
# =================================================================
# Total params: 15,764,508
# Trainable params: 9,762,460
# Non-trainable params: 6,002,048
# _________________________________________________________________

# %%
# F1-Score метрика для каждой эпохи
class F1Metrics(tensorflow.keras.callbacks.Callback):
    def __init__(self, X_val, y_val):
        super().__init__()
        self.X_val = X_val
        self.y_val = y_val
    
    def on_epoch_end(self, epoch, logs=None):
        y_pred = np.argmax(self.model.predict(self.X_val), axis=1)
        f1 = f1_score(self.y_val, y_pred, average='macro')
        print(f"Val F1-Score: {f1:.4f}")
        logs['val_f1'] = f1
# Out:
# Epoch 1/30
# 395/397 [============================>.] - ETA: 0s - loss: 1.8140 - accuracy: 0.5388WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 2s 7ms/step
# Val F1-Score: 0.2439
# 397/397 [==============================] - 17s 31ms/step - loss: 1.8127 - accuracy: 0.5393 - val_loss: 1.6298 - val_accuracy: 0.5700 - lr: 0.0010 - val_f1: 0.2439
# Epoch 2/30
# 397/397 [==============================] - ETA: 0s - loss: 1.5308 - accuracy: 0.5916WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.3554
# 397/397 [==============================] - 12s 31ms/step - loss: 1.5308 - accuracy: 0.5916 - val_loss: 1.5225 - val_accuracy: 0.6100 - lr: 0.0010 - val_f1: 0.3554
# Epoch 3/30
# 396/397 [============================>.] - ETA: 0s - loss: 1.4083 - accuracy: 0.6119WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 6ms/step
# Val F1-Score: 0.3882
# 397/397 [==============================] - 12s 30ms/step - loss: 1.4082 - accuracy: 0.6121 - val_loss: 1.5016 - val_accuracy: 0.6122 - lr: 0.0010 - val_f1: 0.3882
# Epoch 4/30
# 396/397 [============================>.] - ETA: 0s - loss: 1.3022 - accuracy: 0.6325WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.3934
# 397/397 [==============================] - 11s 28ms/step - loss: 1.3023 - accuracy: 0.6325 - val_loss: 1.4943 - val_accuracy: 0.6090 - lr: 0.0010 - val_f1: 0.3934
# Epoch 5/30
# 397/397 [==============================] - ETA: 0s - loss: 1.1916 - accuracy: 0.6521WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 6ms/step
# Val F1-Score: 0.3949
# 397/397 [==============================] - 12s 29ms/step - loss: 1.1916 - accuracy: 0.6521 - val_loss: 1.5127 - val_accuracy: 0.6079 - lr: 0.0010 - val_f1: 0.3949
# Epoch 6/30
# 396/397 [============================>.] - ETA: 0s - loss: 1.0860 - accuracy: 0.6733WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.3962
# 397/397 [==============================] - 12s 31ms/step - loss: 1.0860 - accuracy: 0.6733 - val_loss: 1.5702 - val_accuracy: 0.6013 - lr: 0.0010 - val_f1: 0.3962
# Epoch 7/30
# 395/397 [============================>.] - ETA: 0s - loss: 0.8040 - accuracy: 0.7469WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.4127
# 397/397 [==============================] - 12s 31ms/step - loss: 0.8034 - accuracy: 0.7472 - val_loss: 1.6431 - val_accuracy: 0.6002 - lr: 2.0000e-04 - val_f1: 0.4127
# Epoch 8/30
# 397/397 [==============================] - ETA: 0s - loss: 0.6426 - accuracy: 0.7974WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 2s 8ms/step
# Val F1-Score: 0.4226
# 397/397 [==============================] - 12s 31ms/step - loss: 0.6426 - accuracy: 0.7974 - val_loss: 1.7446 - val_accuracy: 0.5939 - lr: 2.0000e-04 - val_f1: 0.4226
# Epoch 9/30
# 396/397 [============================>.] - ETA: 0s - loss: 0.5197 - accuracy: 0.8360WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 6ms/step
# Val F1-Score: 0.4205
# 397/397 [==============================] - 12s 30ms/step - loss: 0.5198 - accuracy: 0.8360 - val_loss: 1.7912 - val_accuracy: 0.5939 - lr: 4.0000e-05 - val_f1: 0.4205
# Epoch 10/30
# 397/397 [==============================] - ETA: 0s - loss: 0.4830 - accuracy: 0.8492WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.4185
# 397/397 [==============================] - 11s 29ms/step - loss: 0.4830 - accuracy: 0.8492 - val_loss: 1.8272 - val_accuracy: 0.5960 - lr: 4.0000e-05 - val_f1: 0.4185
# Epoch 11/30
# 395/397 [============================>.] - ETA: 0s - loss: 0.4619 - accuracy: 0.8551WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.4184
# 397/397 [==============================] - 12s 30ms/step - loss: 0.4618 - accuracy: 0.8551 - val_loss: 1.8382 - val_accuracy: 0.5958 - lr: 8.0000e-06 - val_f1: 0.4184
# Epoch 12/30
# 396/397 [============================>.] - ETA: 0s - loss: 0.4524 - accuracy: 0.8589WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 6ms/step
# Val F1-Score: 0.4194
# 397/397 [==============================] - 12s 29ms/step - loss: 0.4522 - accuracy: 0.8590 - val_loss: 1.8471 - val_accuracy: 0.5960 - lr: 8.0000e-06 - val_f1: 0.4194
# Epoch 13/30
# 396/397 [============================>.] - ETA: 0s - loss: 0.4488 - accuracy: 0.8600WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.4192
# 397/397 [==============================] - 12s 29ms/step - loss: 0.4491 - accuracy: 0.8599 - val_loss: 1.8494 - val_accuracy: 0.5968 - lr: 1.6000e-06 - val_f1: 0.4192
# Epoch 14/30
# 397/397 [==============================] - ETA: 0s - loss: 0.4458 - accuracy: 0.8608WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.4195
# 397/397 [==============================] - 12s 30ms/step - loss: 0.4458 - accuracy: 0.8608 - val_loss: 1.8514 - val_accuracy: 0.5966 - lr: 1.6000e-06 - val_f1: 0.4195
# Epoch 15/30
# 396/397 [============================>.] - ETA: 0s - loss: 0.4460 - accuracy: 0.8601WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 6ms/step
# Val F1-Score: 0.4189
# 397/397 [==============================] - 11s 29ms/step - loss: 0.4457 - accuracy: 0.8602 - val_loss: 1.8520 - val_accuracy: 0.5963 - lr: 3.2000e-07 - val_f1: 0.4189
# Epoch 16/30
# 397/397 [==============================] - ETA: 0s - loss: 0.4462 - accuracy: 0.8584WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 6ms/step
# Val F1-Score: 0.4195
# 397/397 [==============================] - 11s 27ms/step - loss: 0.4462 - accuracy: 0.8584 - val_loss: 1.8519 - val_accuracy: 0.5966 - lr: 3.2000e-07 - val_f1: 0.4195
# Epoch 17/30
# 397/397 [==============================] - ETA: 0s - loss: 0.4486 - accuracy: 0.8601WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.4200
# 397/397 [==============================] - 11s 28ms/step - loss: 0.4486 - accuracy: 0.8601 - val_loss: 1.8530 - val_accuracy: 0.5969 - lr: 6.4000e-08 - val_f1: 0.4200
# Epoch 18/30
# 397/397 [==============================] - ETA: 0s - loss: 0.4462 - accuracy: 0.8598WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 6ms/step
# Val F1-Score: 0.4196
# 397/397 [==============================] - 11s 28ms/step - loss: 0.4462 - accuracy: 0.8598 - val_loss: 1.8527 - val_accuracy: 0.5966 - lr: 6.4000e-08 - val_f1: 0.4196
# Epoch 19/30
# 396/397 [============================>.] - ETA: 0s - loss: 0.4446 - accuracy: 0.8605WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 6ms/step
# Val F1-Score: 0.4195
# 397/397 [==============================] - 12s 29ms/step - loss: 0.4449 - accuracy: 0.8603 - val_loss: 1.8521 - val_accuracy: 0.5969 - lr: 1.2800e-08 - val_f1: 0.4195
# Epoch 20/30
# 397/397 [==============================] - ETA: 0s - loss: 0.4461 - accuracy: 0.8619WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.4196
# 397/397 [==============================] - 12s 29ms/step - loss: 0.4461 - accuracy: 0.8619 - val_loss: 1.8530 - val_accuracy: 0.5969 - lr: 1.2800e-08 - val_f1: 0.4196
# Epoch 21/30
# 396/397 [============================>.] - ETA: 0s - loss: 0.4432 - accuracy: 0.8604WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.4191
# 397/397 [==============================] - 11s 29ms/step - loss: 0.4433 - accuracy: 0.8603 - val_loss: 1.8528 - val_accuracy: 0.5969 - lr: 2.5600e-09 - val_f1: 0.4191
# Epoch 22/30
# 395/397 [============================>.] - ETA: 0s - loss: 0.4440 - accuracy: 0.8627WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 6ms/step
# Val F1-Score: 0.4196
# 397/397 [==============================] - 11s 29ms/step - loss: 0.4441 - accuracy: 0.8626 - val_loss: 1.8525 - val_accuracy: 0.5969 - lr: 2.5600e-09 - val_f1: 0.4196
# Epoch 23/30
# 395/397 [============================>.] - ETA: 0s - loss: 0.4456 - accuracy: 0.8611WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 6ms/step
# Val F1-Score: 0.4193
# 397/397 [==============================] - 11s 29ms/step - loss: 0.4460 - accuracy: 0.8609 - val_loss: 1.8519 - val_accuracy: 0.5964 - lr: 5.1200e-10 - val_f1: 0.4193
# Epoch 24/30
# 395/397 [============================>.] - ETA: 0s - loss: 0.4451 - accuracy: 0.8600WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.4189
# 397/397 [==============================] - 11s 28ms/step - loss: 0.4450 - accuracy: 0.8599 - val_loss: 1.8522 - val_accuracy: 0.5964 - lr: 5.1200e-10 - val_f1: 0.4189
# Epoch 25/30
# 396/397 [============================>.] - ETA: 0s - loss: 0.4438 - accuracy: 0.8615WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.4197
# 397/397 [==============================] - 12s 29ms/step - loss: 0.4437 - accuracy: 0.8615 - val_loss: 1.8523 - val_accuracy: 0.5972 - lr: 1.0240e-10 - val_f1: 0.4197
# Epoch 26/30
# 396/397 [============================>.] - ETA: 0s - loss: 0.4470 - accuracy: 0.8613WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.4197
# 397/397 [==============================] - 12s 31ms/step - loss: 0.4473 - accuracy: 0.8612 - val_loss: 1.8516 - val_accuracy: 0.5966 - lr: 1.0240e-10 - val_f1: 0.4197
# Epoch 27/30
# 397/397 [==============================] - ETA: 0s - loss: 0.4431 - accuracy: 0.8628WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.4192
# 397/397 [==============================] - 11s 28ms/step - loss: 0.4431 - accuracy: 0.8628 - val_loss: 1.8518 - val_accuracy: 0.5969 - lr: 2.0480e-11 - val_f1: 0.4192
# Epoch 28/30
# 395/397 [============================>.] - ETA: 0s - loss: 0.4460 - accuracy: 0.8603WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.4192
# 397/397 [==============================] - 11s 28ms/step - loss: 0.4457 - accuracy: 0.8604 - val_loss: 1.8527 - val_accuracy: 0.5964 - lr: 2.0480e-11 - val_f1: 0.4192
# Epoch 29/30
# 396/397 [============================>.] - ETA: 0s - loss: 0.4440 - accuracy: 0.8608WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.4195
# 397/397 [==============================] - 11s 29ms/step - loss: 0.4440 - accuracy: 0.8608 - val_loss: 1.8527 - val_accuracy: 0.5966 - lr: 4.0960e-12 - val_f1: 0.4195
# Epoch 30/30
# 397/397 [==============================] - ETA: 0s - loss: 0.4484 - accuracy: 0.8601WARNING:tensorflow:Early stopping conditioned on metric `val_f1` which is not available. Available metrics are: loss,accuracy,val_loss,val_accuracy
# 199/199 [==============================] - 1s 7ms/step
# Val F1-Score: 0.4195
# 397/397 [==============================] - 12s 31ms/step - loss: 0.4484 - accuracy: 0.8601 - val_loss: 1.8522 - val_accuracy: 0.5972 - lr: 4.0960e-12 - val_f1: 0.4195

# %%
# Разделение данных
X_train_split, X_val, y_train_split, y_val = train_test_split(
    X_train, y, test_size=0.2, random_state=42, stratify=y
)

# %%
# Обучение модели RNN
history = model.fit(
    X_train_split, y_train_split,
    validation_data=(X_val, y_val),
    epochs=30, # Кол-во эпох
    batch_size=64, # Батчфайл
    callbacks=[
        EarlyStopping(monitor='val_f1', patience=3, mode='max', restore_best_weights=True),
        ReduceLROnPlateau(monitor='val_loss', factor=0.2, patience=2),
        F1Metrics(X_val, y_val)
    ]
)

# %%
# Визуализация
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss')
plt.legend()
plt.show()

# %%
# Сохранение файла
test_pred = np.argmax(model.predict(X_test), axis=1)
submission = pd.DataFrame({
    'id': test_df['id'],
    'target': label_encoder.inverse_transform(test_pred)
})
submission.to_csv('submissions/submission.csv', index=False)
# Out:
# 249/249 [==============================] - 2s 6ms/step
